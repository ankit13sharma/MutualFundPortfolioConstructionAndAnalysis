# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
# %load_ext autoreload
# %autoreload 2
import utils as utils

# %%
symbols = pd.read_csv('top_direct_mutual_funds_india_csv.csv')
symbols.head()
# Out:
#           Symbol                                       Company name  \
# 0  0P0000XVXX.BO  Aditya Birla Sun Life Corporate Bond Fund Grow...
# 1  0P0000XVWT.BO  Aditya Birla Sun Life Government Securities Fu...
# 2  0P0001BNS5.BO  Aditya Birla Sun Life Government Securities Fu...
# 3  0P0000XVX0.BO  Aditya Birla Sun Life Income Fund Growth Direc...
# 4  0P0000XVXP.BO  Aditya Birla Sun Life Regular Savings Fund Dir...
#
#   52-wk high 52-wk low  Last price 52-wk high chg. 52-wk high chg. %  \
# 0      86.68     77.09       88.32            1.64             0.019
# 1       66.7     59.94       67.19            0.49            0.0073
# 2          -         -       67.19               -                 -
# 3     104.06     91.12      105.29            1.23            0.0118
# 4      49.52     37.32       51.63            2.12            0.0427
#
#   52-wk low chg. 52-wk low chg. %  50-DMA  50-DMA chg.  50-DMA chg. %  \
# 0          11.23           0.1457   88.13         0.19         0.0022
# 1           7.25            0.121   67.29        -0.10        -0.0015
# 2              -                -   67.29        -0.10        -0.0015
# 3          14.17           0.1555  105.23         0.06         0.0006
# 4          14.31           0.3836   51.22         0.41         0.0081
#
#    200-DMA chg. %  200-DMA chg.  200-DMA
# 0          0.0147          1.28    87.04
# 1          0.0119          0.79    66.40
# 2          0.0119          0.79    66.40
# 3          0.0142          1.47   103.81
# 4          0.0368          1.83    49.80

# %%
# mf_list = ["0P0000XUZ6.BO", "0P0000XWAT.BO", "0P0000XWAK.BO","0P0000XW00.BO"]
mf_list = symbols['Symbol']

# %%
data = yf.Ticker(mf_list[0]).get_info()
data
# Out:
# {'exchange': 'BSE',
#  'shortName': 'Aditya Birla Sun Life Corporate',
#  'longName': 'Aditya Birla Sun Life Corporate Bond Fund Growth Direct Plan',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '19800000',
#  'quoteType': 'MUTUALFUND',
#  'symbol': '0P0000XVXX.BO',
#  'market': 'in_market',
#  'annualHoldingsTurnover': 4.717,
#  'enterpriseToRevenue': None,
#  'beta3Year': 0.96,
#  'profitMargins': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': None,
#  'morningStarRiskRating': 2,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'fundInceptionDate': 1356998400,
#  'annualReportExpenseRatio': 0.0027,
#  'totalAssets': 2256856064,
#  'bookValue': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': None,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': None,
#  'nextFiscalYearEnd': None,
#  'yield': 0,
#  'mostRecentQuarter': None,
#  'enterpriseValue': None,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': 5,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': None,
#  'pegRatio': None,
#  'ytdReturn': 0.0214,
#  'forwardPE': None,
#  'maxAge': 1,
#  'lastCapGain': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'address1': 'Aditya Birla Sun Life AMC Ltd',
#  'address2': 'One India Bulls Centre ,Tower 1, 17th Flr,',
#  'address3': 'Jupiter Mill Compound,841,S.B. Marg,',
#  'longBusinessSummary': 'The investment objective of the scheme is to generate optimal returns with high liquidity through active management of the portfolio by investing in High Quality Debt and Money Market Instruments.',
#  'companyOfficers': [],
#  'previousClose': 88.3965,
#  'regularMarketOpen': None,
#  'twoHundredDayAverage': 87.05981,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': None,
#  'navPrice': None,
#  'averageDailyVolume10Day': 0,
#  'regularMarketPreviousClose': 88.3965,
#  'fiftyDayAverage': 88.13761,
#  'trailingAnnualDividendRate': None,
#  'open': None,
#  'toCurrency': None,
#  'averageVolume10days': 0,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': None,
#  'currency': 'INR',
#  'regularMarketVolume': None,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 0,
#  'dayLow': None,
#  'ask': None,
#  'askSize': None,
#  'volume': None,
#  'fiftyTwoWeekHigh': 86.6776,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 77.0866,
#  'bid': None,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': None,
#  'dayHigh': None,
#  'regularMarketPrice': 88.4633,
#  'logo_url': ''}

# %%
len(data.keys())
# Out:
# 102

# %%
df = pd.DataFrame(index = data.keys())  
for mf in mf_list:
    data = yf.Ticker(mf).get_info()
    try:
        df[data['longName']] =  data.values()
    except ValueError:
        df[data['longName']] =  [data[ind] if ind in data.keys()  else np.nan for ind in df.index]
    time.sleep(2)

# %%
df.shape
# Out:
# (102, 83)

# %%
df.columns = df.loc['longName'][:]

# %%
df.to_csv('./mf_info_by_attributes.csv')

# %%
df2 = df.transpose()
df2.head()
# Out:
#                                                    exchange  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...      BSE
# Aditya Birla Sun Life Government Securities Fun...      BSE
# Aditya Birla Sun Life Income Fund Growth Direct...      BSE
# Aditya Birla Sun Life Regular Savings Fund Dire...      BSE
# Axis Bluechip Fund Direct Plan Growth                   BSE
#
#                                                                           shortName  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...  Aditya Birla Sun Life Corporate
# Aditya Birla Sun Life Government Securities Fun...  Aditya Birla Sun Life Governmen
# Aditya Birla Sun Life Income Fund Growth Direct...  Aditya Birla Sun Life Income Fu
# Aditya Birla Sun Life Regular Savings Fund Dire...  Aditya Birla Sun Life Reg Savin
# Axis Bluechip Fund Direct Plan Growth               Axis Bluechip Fund Direct Plan
#
#                                                                                              longName  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...  Aditya Birla Sun Life Corporate Bond Fund Grow...
# Aditya Birla Sun Life Government Securities Fun...  Aditya Birla Sun Life Government Securities Fu...
# Aditya Birla Sun Life Income Fund Growth Direct...  Aditya Birla Sun Life Income Fund Growth Direc...
# Aditya Birla Sun Life Regular Savings Fund Dire...  Aditya Birla Sun Life Regular Savings Fund Dir...
# Axis Bluechip Fund Direct Plan Growth                           Axis Bluechip Fund Direct Plan Growth
#
#                                                    exchangeTimezoneName  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...         Asia/Kolkata
# Aditya Birla Sun Life Government Securities Fun...         Asia/Kolkata
# Aditya Birla Sun Life Income Fund Growth Direct...         Asia/Kolkata
# Aditya Birla Sun Life Regular Savings Fund Dire...         Asia/Kolkata
# Axis Bluechip Fund Direct Plan Growth                      Asia/Kolkata
#
#                                                    exchangeTimezoneShortName  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...                       IST
# Aditya Birla Sun Life Government Securities Fun...                       IST
# Aditya Birla Sun Life Income Fund Growth Direct...                       IST
# Aditya Birla Sun Life Regular Savings Fund Dire...                       IST
# Axis Bluechip Fund Direct Plan Growth                                    IST
#
#                                                    isEsgPopulated  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...          False
# Aditya Birla Sun Life Government Securities Fun...          False
# Aditya Birla Sun Life Income Fund Growth Direct...          False
# Aditya Birla Sun Life Regular Savings Fund Dire...          False
# Axis Bluechip Fund Direct Plan Growth                       False
#
#                                                    gmtOffSetMilliseconds  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...              19800000
# Aditya Birla Sun Life Government Securities Fun...              19800000
# Aditya Birla Sun Life Income Fund Growth Direct...              19800000
# Aditya Birla Sun Life Regular Savings Fund Dire...              19800000
# Axis Bluechip Fund Direct Plan Growth                           19800000
#
#                                                      quoteType         symbol  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...  MUTUALFUND  0P0000XVXX.BO
# Aditya Birla Sun Life Government Securities Fun...  MUTUALFUND  0P0001BNS5.BO
# Aditya Birla Sun Life Income Fund Growth Direct...  MUTUALFUND  0P0000XVX0.BO
# Aditya Birla Sun Life Regular Savings Fund Dire...  MUTUALFUND  0P0000XVXP.BO
# Axis Bluechip Fund Direct Plan Growth               MUTUALFUND  0P0000XVTL.BO
#
#                                                        market  ...  \
# longName                                                       ...
# Aditya Birla Sun Life Corporate Bond Fund Growt...  in_market  ...
# Aditya Birla Sun Life Government Securities Fun...  in_market  ...
# Aditya Birla Sun Life Income Fund Growth Direct...  in_market  ...
# Aditya Birla Sun Life Regular Savings Fund Dire...  in_market  ...
# Axis Bluechip Fund Direct Plan Growth               in_market  ...
#
#                                                    fromCurrency  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...         None
# Aditya Birla Sun Life Government Securities Fun...         None
# Aditya Birla Sun Life Income Fund Growth Direct...         None
# Aditya Birla Sun Life Regular Savings Fund Dire...         None
# Axis Bluechip Fund Direct Plan Growth                      None
#
#                                                    fiveYearAvgDividendYield  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...                     None
# Aditya Birla Sun Life Government Securities Fun...                     None
# Aditya Birla Sun Life Income Fund Growth Direct...                     None
# Aditya Birla Sun Life Regular Savings Fund Dire...                     None
# Axis Bluechip Fund Direct Plan Growth                                  None
#
#                                                    fiftyTwoWeekLow   bid  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...         77.0866  None
# Aditya Birla Sun Life Government Securities Fun...            None  None
# Aditya Birla Sun Life Income Fund Growth Direct...         91.1172  None
# Aditya Birla Sun Life Regular Savings Fund Dire...          37.318  None
# Axis Bluechip Fund Direct Plan Growth                        25.54  None
#
#                                                    tradeable dividendYield  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...     False          None
# Aditya Birla Sun Life Government Securities Fun...     False          None
# Aditya Birla Sun Life Income Fund Growth Direct...     False          None
# Aditya Birla Sun Life Regular Savings Fund Dire...     False          None
# Axis Bluechip Fund Direct Plan Growth                  False          None
#
#                                                    bidSize dayHigh  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...    None    None
# Aditya Birla Sun Life Government Securities Fun...    None    None
# Aditya Birla Sun Life Income Fund Growth Direct...    None    None
# Aditya Birla Sun Life Regular Savings Fund Dire...    None    None
# Axis Bluechip Fund Direct Plan Growth                 None    None
#
#                                                    regularMarketPrice logo_url
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...            88.4633
# Aditya Birla Sun Life Government Securities Fun...            67.3372
# Aditya Birla Sun Life Income Fund Growth Direct...            105.451
# Aditya Birla Sun Life Regular Savings Fund Dire...            51.7244
# Axis Bluechip Fund Direct Plan Growth                           46.92
#
# [5 rows x 102 columns]

# %%
df2.to_csv('./mf_info_by_fund_name.csv')

# %%
df2 = df2.replace('',np.nan)
df2.isna().sum()
# Out:
# exchange                      0
# shortName                     0
# longName                      0
# exchangeTimezoneName          0
# exchangeTimezoneShortName     0
#                              ..
# dividendYield                83
# bidSize                      83
# dayHigh                      83
# regularMarketPrice            0
# logo_url                     83
# Length: 102, dtype: int64

# %%
df2 = df2.dropna(axis =1, how = 'all')
df2.isna().sum()
# Out:
# exchange                       0
# shortName                      0
# longName                       0
# exchangeTimezoneName           0
# exchangeTimezoneShortName      0
# isEsgPopulated                 0
# gmtOffSetMilliseconds          0
# quoteType                      0
# symbol                         0
# market                         0
# annualHoldingsTurnover         0
# beta3Year                     14
# morningStarRiskRating          0
# fundInceptionDate              0
# annualReportExpenseRatio       0
# totalAssets                   41
# yield                          0
# priceHint                      0
# morningStarOverallRating       0
# ytdReturn                      0
# maxAge                         0
# address1                       0
# address2                       4
# address3                       7
# longBusinessSummary            0
# companyOfficers                0
# previousClose                  0
# twoHundredDayAverage           0
# averageDailyVolume10Day        4
# regularMarketPreviousClose     0
# fiftyDayAverage                0
# averageVolume10days            4
# currency                       0
# averageVolume                  4
# fiftyTwoWeekHigh               4
# fiftyTwoWeekLow                4
# tradeable                      0
# regularMarketPrice             0
# dtype: int64

# %%
df2.dtypes
# Out:
# exchange                       object
# shortName                      object
# longName                       object
# exchangeTimezoneName           object
# exchangeTimezoneShortName      object
# isEsgPopulated                   bool
# gmtOffSetMilliseconds          object
# quoteType                      object
# symbol                         object
# market                         object
# annualHoldingsTurnover        float64
# beta3Year                     float64
# morningStarRiskRating           int64
# fundInceptionDate               int64
# annualReportExpenseRatio      float64
# totalAssets                   float64
# yield                           int64
# priceHint                       int64
# morningStarOverallRating        int64
# ytdReturn                     float64
# maxAge                          int64
# address1                       object
# address2                       object
# address3                       object
# longBusinessSummary            object
# companyOfficers                object
# previousClose                 float64
# twoHundredDayAverage          float64
# averageDailyVolume10Day       float64
# regularMarketPreviousClose    float64
# fiftyDayAverage               float64
# averageVolume10days           float64
# currency                       object
# averageVolume                 float64
# fiftyTwoWeekHigh              float64
# fiftyTwoWeekLow               float64
# tradeable                        bool
# regularMarketPrice            float64
# dtype: object

# %%
df2.to_csv('./mf_info_by_fund_name_non_empty.csv')

# %%
imp_columns = [column for column in df2.columns if df2.dtypes[column] not in ['object','bool']]
imp_columns
# Out:
# ['annualHoldingsTurnover',
#  'beta3Year',
#  'morningStarRiskRating',
#  'fundInceptionDate',
#  'annualReportExpenseRatio',
#  'totalAssets',
#  'yield',
#  'priceHint',
#  'morningStarOverallRating',
#  'ytdReturn',
#  'maxAge',
#  'previousClose',
#  'twoHundredDayAverage',
#  'averageDailyVolume10Day',
#  'regularMarketPreviousClose',
#  'fiftyDayAverage',
#  'averageVolume10days',
#  'averageVolume',
#  'fiftyTwoWeekHigh',
#  'fiftyTwoWeekLow',
#  'regularMarketPrice']

# %%
dataset = df2[imp_columns]
dataset.dropna(axis=1, how = 'any',inplace=True)
dataset.isna().sum()
# Out:
# C:\Python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# annualHoldingsTurnover        0
# morningStarRiskRating         0
# fundInceptionDate             0
# annualReportExpenseRatio      0
# yield                         0
# priceHint                     0
# morningStarOverallRating      0
# ytdReturn                     0
# maxAge                        0
# previousClose                 0
# twoHundredDayAverage          0
# regularMarketPreviousClose    0
# fiftyDayAverage               0
# regularMarketPrice            0
# dtype: int64

# %%
dataset.head()
# Out:
#                                                     annualHoldingsTurnover  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...                  4.7170
# Aditya Birla Sun Life Government Securities Fun...                 13.1504
# Aditya Birla Sun Life Income Fund Growth Direct...                 19.5812
# Aditya Birla Sun Life Regular Savings Fund Dire...                  3.9256
# Axis Bluechip Fund Direct Plan Growth                               1.4238
#
#                                                     morningStarRiskRating  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...                      2
# Aditya Birla Sun Life Government Securities Fun...                      4
# Aditya Birla Sun Life Income Fund Growth Direct...                      4
# Aditya Birla Sun Life Regular Savings Fund Dire...                      5
# Axis Bluechip Fund Direct Plan Growth                                   2
#
#                                                     fundInceptionDate  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...         1356998400
# Aditya Birla Sun Life Government Securities Fun...         1356998400
# Aditya Birla Sun Life Income Fund Growth Direct...         1356998400
# Aditya Birla Sun Life Regular Savings Fund Dire...         1356998400
# Axis Bluechip Fund Direct Plan Growth                      1356998400
#
#                                                     annualReportExpenseRatio  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...                    0.0027
# Aditya Birla Sun Life Government Securities Fun...                    0.0057
# Aditya Birla Sun Life Income Fund Growth Direct...                    0.0080
# Aditya Birla Sun Life Regular Savings Fund Dire...                    0.0094
# Axis Bluechip Fund Direct Plan Growth                                 0.0090
#
#                                                     yield  priceHint  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...      0          2
# Aditya Birla Sun Life Government Securities Fun...      0          2
# Aditya Birla Sun Life Income Fund Growth Direct...      0          2
# Aditya Birla Sun Life Regular Savings Fund Dire...      0          2
# Axis Bluechip Fund Direct Plan Growth                   0          2
#
#                                                     morningStarOverallRating  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...                         5
# Aditya Birla Sun Life Government Securities Fun...                         5
# Aditya Birla Sun Life Income Fund Growth Direct...                         5
# Aditya Birla Sun Life Regular Savings Fund Dire...                         5
# Axis Bluechip Fund Direct Plan Growth                                      5
#
#                                                     ytdReturn  maxAge  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...     0.0214       1
# Aditya Birla Sun Life Government Securities Fun...     0.0109       1
# Aditya Birla Sun Life Income Fund Growth Direct...     0.0153       1
# Aditya Birla Sun Life Regular Savings Fund Dire...     0.0897       1
# Axis Bluechip Fund Direct Plan Growth                  0.1098       1
#
#                                                     previousClose  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...        88.3965
# Aditya Birla Sun Life Government Securities Fun...        67.2629
# Aditya Birla Sun Life Income Fund Growth Direct...       105.3140
# Aditya Birla Sun Life Regular Savings Fund Dire...        51.7211
# Axis Bluechip Fund Direct Plan Growth                     46.8800
#
#                                                     twoHundredDayAverage  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...             87.059810
# Aditya Birla Sun Life Government Securities Fun...             66.406610
# Aditya Birla Sun Life Income Fund Growth Direct...            103.827965
# Aditya Birla Sun Life Regular Savings Fund Dire...             49.831160
# Axis Bluechip Fund Direct Plan Growth                          43.855408
#
#                                                     regularMarketPreviousClose  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...                     88.3965
# Aditya Birla Sun Life Government Securities Fun...                     67.2629
# Aditya Birla Sun Life Income Fund Growth Direct...                    105.3140
# Aditya Birla Sun Life Regular Savings Fund Dire...                     51.7211
# Axis Bluechip Fund Direct Plan Growth                                  46.8800
#
#                                                     fiftyDayAverage  \
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...        88.137610
# Aditya Birla Sun Life Government Securities Fun...        67.291080
# Aditya Birla Sun Life Income Fund Growth Direct...       105.234116
# Aditya Birla Sun Life Regular Savings Fund Dire...        51.233757
# Axis Bluechip Fund Direct Plan Growth                     46.184570
#
#                                                     regularMarketPrice  labels
# longName
# Aditya Birla Sun Life Corporate Bond Fund Growt...             88.4633       0
# Aditya Birla Sun Life Government Securities Fun...             67.3372       0
# Aditya Birla Sun Life Income Fund Growth Direct...            105.4510       0
# Aditya Birla Sun Life Regular Savings Fund Dire...             51.7244       0
# Axis Bluechip Fund Direct Plan Growth                          46.9200       0

# %%
mms = MinMaxScaler()
mms.fit(dataset)
data_transformed = mms.transform(dataset)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
km = KMeans(n_clusters=4)
kmn = km.fit(data_transformed)
dataset['labels'] = kmn.labels_
# Out:
# C:\Python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dataset.groupby(by = 'labels').mean()
# Out:
#         annualHoldingsTurnover  morningStarRiskRating  fundInceptionDate  \
# labels
# 0                     4.511651               2.886792       1.365272e+09
# 1                     8.682180               1.200000       1.356998e+09
# 2                     0.769635               3.217391       1.362892e+09
# 3                     2.678700               0.000000       1.488715e+09
#
#         annualReportExpenseRatio  yield  priceHint  morningStarOverallRating  \
# labels
# 0                       0.007083    0.0        2.0                  4.773585
# 1                       0.001860    0.0        2.0                  3.000000
# 2                       0.015822    0.0        2.0                  4.391304
# 3                       0.009800    0.0        2.0                  0.000000
#
#         ytdReturn  maxAge  previousClose  twoHundredDayAverage  \
# labels
# 0        0.040755     1.0      44.817543             44.120974
# 1        0.017180     1.0    2632.518000           2609.017600
# 2        0.222365     1.0     101.498096            101.601578
# 3        0.131800     1.0      17.413250             16.261488
#
#         regularMarketPreviousClose  fiftyDayAverage  regularMarketPrice
# labels
# 0                        44.817543        45.550191           44.838694
# 1                      2632.518000      2629.476180         2632.920000
# 2                       101.498096       115.741806          101.558661
# 3                        17.413250        17.177397           17.397850

# %%
dataset.groupby(by = 'labels').count()
# Out:
#         annualHoldingsTurnover  morningStarRiskRating  fundInceptionDate  \
# labels
# 0                           53                     53                 53
# 1                            5                      5                  5
# 2                           23                     23                 23
# 3                            2                      2                  2
#
#         annualReportExpenseRatio  yield  priceHint  morningStarOverallRating  \
# labels
# 0                             53     53         53                        53
# 1                              5      5          5                         5
# 2                             23     23         23                        23
# 3                              2      2          2                         2
#
#         ytdReturn  maxAge  previousClose  twoHundredDayAverage  \
# labels
# 0              53      53             53                    53
# 1               5       5              5                     5
# 2              23      23             23                    23
# 3               2       2              2                     2
#
#         regularMarketPreviousClose  fiftyDayAverage  regularMarketPrice
# labels
# 0                               53               53                  53
# 1                                5                5                   5
# 2                               23               23                  23
# 3                                2                2                   2

# %%
dataset2 = dataset[dataset['labels'] == 2]

# %%
dataset2.head()
# Out:
#                                                     annualHoldingsTurnover  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...                  1.1029
# Axis Midcap Fund Direct Plan Growth                                 0.6369
# BOI AXA Tax Advantage Fund-Direct Plan- Growth                      0.8033
# Canara Robeco Bluechip Equity Fund Direct Plan ...                  0.9430
# Canara Robeco Emerging Equities-Direct Plan-Gro...                  0.8596
#
#                                                     morningStarRiskRating  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...                      2
# Axis Midcap Fund Direct Plan Growth                                     1
# BOI AXA Tax Advantage Fund-Direct Plan- Growth                          5
# Canara Robeco Bluechip Equity Fund Direct Plan ...                      3
# Canara Robeco Emerging Equities-Direct Plan-Gro...                      5
#
#                                                     fundInceptionDate  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...         1356998400
# Axis Midcap Fund Direct Plan Growth                        1356998400
# BOI AXA Tax Advantage Fund-Direct Plan- Growth             1356998400
# Canara Robeco Bluechip Equity Fund Direct Plan ...         1356998400
# Canara Robeco Emerging Equities-Direct Plan-Gro...         1356998400
#
#                                                     annualReportExpenseRatio  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...                    0.0110
# Axis Midcap Fund Direct Plan Growth                                   0.0116
# BOI AXA Tax Advantage Fund-Direct Plan- Growth                        0.0181
# Canara Robeco Bluechip Equity Fund Direct Plan ...                    0.0172
# Canara Robeco Emerging Equities-Direct Plan-Gro...                    0.0093
#
#                                                     yield  priceHint  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...      0          2
# Axis Midcap Fund Direct Plan Growth                     0          2
# BOI AXA Tax Advantage Fund-Direct Plan- Growth          0          2
# Canara Robeco Bluechip Equity Fund Direct Plan ...      0          2
# Canara Robeco Emerging Equities-Direct Plan-Gro...      0          2
#
#                                                     morningStarOverallRating  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...                         5
# Axis Midcap Fund Direct Plan Growth                                        5
# BOI AXA Tax Advantage Fund-Direct Plan- Growth                             4
# Canara Robeco Bluechip Equity Fund Direct Plan ...                         5
# Canara Robeco Emerging Equities-Direct Plan-Gro...                         5
#
#                                                     ytdReturn  maxAge  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...     0.1475       1
# Axis Midcap Fund Direct Plan Growth                    0.2596       1
# BOI AXA Tax Advantage Fund-Direct Plan- Growth         0.2867       1
# Canara Robeco Bluechip Equity Fund Direct Plan ...     0.1580       1
# Canara Robeco Emerging Equities-Direct Plan-Gro...     0.2401       1
#
#                                                     previousClose  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...        74.2924
# Axis Midcap Fund Direct Plan Growth                       69.7100
# BOI AXA Tax Advantage Fund-Direct Plan- Growth           104.3800
# Canara Robeco Bluechip Equity Fund Direct Plan ...        42.2500
# Canara Robeco Emerging Equities-Direct Plan-Gro...       162.7100
#
#                                                     twoHundredDayAverage  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...             68.347435
# Axis Midcap Fund Direct Plan Growth                            61.509853
# BOI AXA Tax Advantage Fund-Direct Plan- Growth                 90.439330
# Canara Robeco Bluechip Equity Fund Direct Plan ...             39.154816
# Canara Robeco Emerging Equities-Direct Plan-Gro...            145.034300
#
#                                                     regularMarketPreviousClose  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...                     74.2924
# Axis Midcap Fund Direct Plan Growth                                    69.7100
# BOI AXA Tax Advantage Fund-Direct Plan- Growth                        104.3800
# Canara Robeco Bluechip Equity Fund Direct Plan ...                     42.2500
# Canara Robeco Emerging Equities-Direct Plan-Gro...                    162.7100
#
#                                                     fiftyDayAverage  \
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...        72.721130
# Axis Midcap Fund Direct Plan Growth                       67.108000
# BOI AXA Tax Advantage Fund-Direct Plan- Growth            99.555145
# Canara Robeco Bluechip Equity Fund Direct Plan ...        41.460570
# Canara Robeco Emerging Equities-Direct Plan-Gro...       157.368850
#
#                                                     regularMarketPrice  labels
# longName
# Axis Long Term Equity Fund Direct Plan Growth O...             74.3636       0
# Axis Midcap Fund Direct Plan Growth                            69.7000       3
# BOI AXA Tax Advantage Fund-Direct Plan- Growth                104.8400       0
# Canara Robeco Bluechip Equity Fund Direct Plan ...             42.2600       0
# Canara Robeco Emerging Equities-Direct Plan-Gro...            163.4400       0

# %%
mms = MinMaxScaler()
mms.fit(dataset2)
data_transformed2 = mms.transform(dataset2)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed2)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
km = KMeans(n_clusters=7)
kmn = km.fit(data_transformed2)
dataset2['labels'] = kmn.labels_
# Out:
# C:\Python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dataset2.groupby(by = 'labels').mean()
# Out:
#         annualHoldingsTurnover  morningStarRiskRating  fundInceptionDate  \
# labels
# 0                     0.853569               3.846154       1.356998e+09
# 1                     0.251450               3.500000       1.356998e+09
# 2                     0.410500               4.000000       1.356998e+09
# 3                     0.362200               1.000000       1.360087e+09
# 4                     3.188300               3.000000       1.385942e+09
# 5                     0.464700               3.000000       1.356998e+09
# 6                     0.590000               3.000000       1.451261e+09
#
#         annualReportExpenseRatio  yield  priceHint  morningStarOverallRating  \
# labels
# 0                       0.011346    0.0        2.0                  4.692308
# 1                       0.015300    0.0        2.0                  3.000000
# 2                       0.063900    0.0        2.0                  4.000000
# 3                       0.017775    0.0        2.0                  4.750000
# 4                       0.016600    0.0        2.0                  2.000000
# 5                       0.034200    0.0        2.0                  4.000000
# 6                       0.000000    0.0        2.0                  5.000000
#
#         ytdReturn  maxAge  previousClose  twoHundredDayAverage  \
# labels
# 0        0.200615     1.0      79.942523             80.214486
# 1        0.162750     1.0     221.286500            240.334870
# 2        0.360700     1.0     205.187000            176.577130
# 3        0.258625     1.0      52.297850             46.652558
# 4        0.282800     1.0      39.440000             35.204224
# 5        0.327400     1.0     368.612000            326.232100
# 6        0.175500     1.0      30.200000             88.754560
#
#         regularMarketPreviousClose  fiftyDayAverage  regularMarketPrice
# labels
# 0                        79.942523        98.535919           80.156138
# 1                       221.286500       263.493705          221.028500
# 2                       205.187000       205.624200          204.580000
# 3                        52.297850        51.381806           52.297100
# 4                        39.440000        39.692940           39.360000
# 5                       368.612000       372.950780          368.529000
# 6                        30.200000        30.312030           30.105000

# %%
dataset2.groupby(by = 'labels').count()
# Out:
#         annualHoldingsTurnover  morningStarRiskRating  fundInceptionDate  \
# labels
# 0                           13                     13                 13
# 1                            2                      2                  2
# 2                            1                      1                  1
# 3                            4                      4                  4
# 4                            1                      1                  1
# 5                            1                      1                  1
# 6                            1                      1                  1
#
#         annualReportExpenseRatio  yield  priceHint  morningStarOverallRating  \
# labels
# 0                             13     13         13                        13
# 1                              2      2          2                         2
# 2                              1      1          1                         1
# 3                              4      4          4                         4
# 4                              1      1          1                         1
# 5                              1      1          1                         1
# 6                              1      1          1                         1
#
#         ytdReturn  maxAge  previousClose  twoHundredDayAverage  \
# labels
# 0              13      13             13                    13
# 1               2       2              2                     2
# 2               1       1              1                     1
# 3               4       4              4                     4
# 4               1       1              1                     1
# 5               1       1              1                     1
# 6               1       1              1                     1
#
#         regularMarketPreviousClose  fiftyDayAverage  regularMarketPrice
# labels
# 0                               13               13                  13
# 1                                2                2                   2
# 2                                1                1                   1
# 3                                4                4                   4
# 4                                1                1                   1
# 5                                1                1                   1
# 6                                1                1                   1

# %%
dataset3 = dataset2[dataset2['labels'] == 5]
dataset3
# Out:
#                                              annualHoldingsTurnover  \
# longName
# Quant Active Fund Growth Option Direct Plan                  0.4647
#
#                                              morningStarRiskRating  \
# longName
# Quant Active Fund Growth Option Direct Plan                      3
#
#                                              fundInceptionDate  \
# longName
# Quant Active Fund Growth Option Direct Plan         1356998400
#
#                                              annualReportExpenseRatio  yield  \
# longName
# Quant Active Fund Growth Option Direct Plan                    0.0342      0
#
#                                              priceHint  \
# longName
# Quant Active Fund Growth Option Direct Plan          2
#
#                                              morningStarOverallRating  \
# longName
# Quant Active Fund Growth Option Direct Plan                         4
#
#                                              ytdReturn  maxAge  previousClose  \
# longName
# Quant Active Fund Growth Option Direct Plan     0.3274       1        368.612
#
#                                              twoHundredDayAverage  \
# longName
# Quant Active Fund Growth Option Direct Plan              326.2321
#
#                                              regularMarketPreviousClose  \
# longName
# Quant Active Fund Growth Option Direct Plan                     368.612
#
#                                              fiftyDayAverage  \
# longName
# Quant Active Fund Growth Option Direct Plan        372.95078
#
#                                              regularMarketPrice  labels
# longName
# Quant Active Fund Growth Option Direct Plan             368.529       5

# %%
mutual_funds = list(dataset2.index)
mutual_funds
# Out:
# ['Axis Long Term Equity Fund Direct Plan Growth Option',
#  'Axis Midcap Fund Direct Plan Growth',
#  'BOI AXA Tax Advantage Fund-Direct Plan- Growth',
#  'Canara Robeco Bluechip Equity Fund Direct Plan Growth',
#  'Canara Robeco Emerging Equities-Direct Plan-Growth Option',
#  'Canara Robeco Equity Taxsaver - Direct Plan - Growth Option',
#  'DSP Tax Saver Fund - Direct Plan - Growth',
#  'Franklin Build India Fund - Direct - Growth',
#  'HDFC Balanced Adv Direct Plan Growth Option',
#  'ICICI Prudential Nifty Next 50 Index Fund Direct Plan Growth',
#  'IDFC Tax Advantage (ELSS) Fund - Direct Plan - Growth',
#  'Invesco India Contra Fund - Direct Plan - Growth',
#  'Invesco India Infrastructure Fund - Direct Pan - Growth Option',
#  'Kotak Emerging Equity Scheme Direct Growth',
#  'Mirae Asset Emerging Bluechip Fund - Direct Plan - Growth',
#  'Mirae Asset Tax Saver Fund -Direct Plan-Growth',
#  'Nippon India Large Cap Fund - Direct Plan - Growth Plan',
#  'Parag Parikh Long Term Equity Direct Growth',
#  'PGIM India Midcap Opportunities Fund Direct Growth',
#  'Quant Absolute Fund Growth Option Direct Plan',
#  'Quant Active Fund Growth Option Direct Plan',
#  'Quant Tax Plan Growth Option Direct Plan',
#  'SBI Small Cap Fund Direct Plan Growth']

# %%
symbols_by_name = {}
for ind in symbols.index:
    symbols_by_name[symbols.loc[ind]['Company name']] = symbols.loc[ind]['Symbol']

# %%
symbols_list = [str(symbols_by_name[key]) for key in mutual_funds]
symbols_list
# Out:
# ['0P0000XVU7.BO',
#  '0P0000XVUH.BO',
#  '0P0000XVZR.BO',
#  '0P0000XW0O.BO',
#  '0P0000XW00.BO',
#  '0P0000XW04.BO',
#  '0P0000XW2T.BO',
#  '0P0000XW55.BO',
#  '0P0001EI12.BO',
#  '0P0000XUYS.BO',
#  '0P0000XV1I.BO',
#  '0P0000XVGR.BO',
#  '0P0000XVH6.BO',
#  '0P0000XV5R.BO',
#  '0P0000XV9V.BO',
#  '0P00017844.BO',
#  '0P0000XVG6.BO',
#  '0P0000YWL1.BO',
#  '0P00011MAT.BO',
#  '0P0000XW4A.BO',
#  '0P0000XW4E.BO',
#  '0P0000XW51.BO',
#  '0P0000XW1B.BO']

# %%
symbols_list = ['0P0000XVU7.BO',
 '0P0000XVUH.BO',
 '0P0000XVZR.BO',
 '0P0000XW0O.BO',
 '0P0000XW00.BO',
 '0P0000XW04.BO',
 '0P0000XW2T.BO',
 '0P0000XW55.BO',
 '0P0001EI12.BO',
 '0P0000XUYS.BO',
 '0P0000XV1I.BO',
 '0P0000XVGR.BO',
 '0P0000XVH6.BO',
 '0P0000XV5R.BO',
 '0P0000XV9V.BO',
 '0P00017844.BO',
 '0P0000XVG6.BO',
 '0P0000YWL1.BO',
 '0P00011MAT.BO',
 '0P0000XW4A.BO',
 '0P0000XW4E.BO',
 '0P0000XW51.BO',
 '0P0000XW1B.BO']

# %%
mf = utils.stock_data(symbols_list, '5y', '1d')
mf = mf['Close']
mf.head(10)
# Out:
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
#
#
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-12:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-18:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-14:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
#
#
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "c:\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\python36\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\python36\lib\site-packages\multitasking\__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 170, in _download_one_threaded
#     actions, period, interval, prepost, proxy, rounding)
#   File "c:\python36\lib\site-packages\yfinance\multi.py", line 185, in _download_one
#     rounding=rounding, many=True)
#   File "c:\python36\lib\site-packages\yfinance\base.py", line 157, in history
#     data = data.json()
#   File "c:\python36\lib\site-packages\requests\models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "c:\python36\lib\json\__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "c:\python36\lib\json\decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "c:\python36\lib\json\decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
